# %%
import numpy as np
import pandas as pd

# %%
demand = pd.read_excel('demand.xlsx')

# %%
demand
# Out:
#     shop  January  February  March  April   May  June  July  August  \
# 0      1      4.4       4.0    4.8    6.8   6.4   6.4   6.4     6.8
# 1      2      4.0       4.0    4.8    6.0   7.2   4.8   6.4     6.8
# 2      3      5.2       6.0    6.8    8.8   8.0   8.0   8.8     8.0
# 3      4      6.0       5.2    7.6    7.2   8.8   8.8   7.2     8.0
# 4      5      4.0       4.8    6.8    5.2   7.2   5.6   6.4     7.6
# 5      6      6.0       6.4    6.0    7.6   7.2   8.8  11.2     9.2
# 6      7      9.2       8.0   11.6   11.2  10.8  10.4  12.4    11.2
# 7      8      7.2       7.6   10.0   12.8  18.8  12.8  13.6    12.4
# 8      9     10.4       9.2   13.6   14.8  16.4  16.0  16.0    11.6
# 9     10      7.6       7.6    7.2    9.6  12.8   9.6  11.2     9.6
# 10    11      8.0      10.0    9.6   12.4  11.6  13.6  14.8    12.8
# 11    12      9.6       7.6   10.4    9.6  14.8  12.0  13.2    14.8
# 12    13     10.0       9.2   10.4   10.4  12.8  14.4  12.8     9.6
# ...

# %%
#I need to know which shops are connected to which warehouses
